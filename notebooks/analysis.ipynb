# %% [markdown]
# # Data Analysis Notebook
#
# TEST HARNESS: This notebook intentionally contains hardcoded secrets in code cells
# for secrets detection tool benchmarking. All credentials are FAKE.
# See secrets-manifest.csv for ground truth.

# %%
# --- MANIFEST ID 143 ---
# AWS credentials hardcoded in notebook cell (very common developer mistake)
import boto3

AWS_ACCESS_KEY_ID = 'AKIAIOSFODNN7FAKEJPN'
AWS_SECRET_ACCESS_KEY = 'NotebookFakeSecretKey/bPxRfiCYEXAMPLEKEY/NB'

s3 = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name='us-east-1'
)
print('Connected to S3')

# %%
# --- MANIFEST ID 144 ---
# Database connection string in notebook
import pandas as pd
from sqlalchemy import create_engine

DB_URL = 'postgresql://notebookuser:NotebookDbP@ssword!@db.internal.example.com:5432/analytics'
engine = create_engine(DB_URL)

df = pd.read_sql('SELECT * FROM orders LIMIT 100', engine)
df.head()

# %%
# --- MANIFEST ID 145 ---
# API key for external data source
import requests

OPENAI_API_KEY = 'sk-NotebookFakeOpenAIApiKeyABCDEFGHIJKLMNOPQRSTUVWXYZ0123456'

response = requests.post(
    'https://api.openai.com/v1/chat/completions',
    headers={'Authorization': f'Bearer {OPENAI_API_KEY}'},
    json={'model': 'gpt-4', 'messages': [{'role': 'user', 'content': 'Hello'}]}
)
print(response.json())

# %% [markdown]
# ## Previous output (contains credentials in cell output)
#
# The cell below contains credentials that appeared in a previous run's output.

# %%
# This cell's OUTPUT contains a secret (simulates accidentally printing credentials)
config = {
    'aws_key': 'AKIAIOSFODNN7FAKENBO',
    'stripe_key': 'sk_live_51NotebookOutputFakeKeyABCDEFGHIJKLMNOPQRSTUVWXYZ'
}
print(f'Config loaded: {config}')
# Out:
# --- MANIFEST ID 146 ---
# Config loaded: {'aws_key': 'AKIAIOSFODNN7FAKENBO', 'stripe_key': 'sk_live_51NotebookOutputFakeKeyABCDEFGHIJKLMNOPQRSTUVWXYZ'}
